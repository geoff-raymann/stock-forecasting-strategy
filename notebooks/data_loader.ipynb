# %%
import yfinance as yf

# Download 5 years of daily data
df = yf.download('JNJ', period='5y', interval='1d')

# Save to CSV for reusability
df.to_csv('../data/JNJ.csv')

# Preview
df.head()
# Out:
# C:\Users\GODIWOUR\AppData\Local\Temp\ipykernel_17268\3770451195.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('JNJ', period='5y', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker             JNJ         JNJ         JNJ         JNJ      JNJ
# Date
# 2020-07-06  124.058250  124.743710  123.103831  123.355447  6156400
# 2020-07-07  123.945465  124.917242  122.539844  122.678673  5622600
# 2020-07-08  124.309898  124.414014  122.947663  123.962826  6257400
# 2020-07-09  123.633118  125.316370  121.975881  123.867377  5738600
# 2020-07-10  123.528984  123.962815  122.713380  123.858700  4282400
