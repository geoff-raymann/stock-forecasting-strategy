# %%
import yfinance as yf

# Download 5 years of daily data
df = yf.download('JNJ', period='5y', interval='1d')

# Save to CSV for reusability
df.to_csv('../data/JNJ.csv')

# Preview
df.head()
# Out:
# C:\Users\GODIWOUR\AppData\Local\Temp\ipykernel_588\3770451195.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('JNJ', period='5y', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             JNJ         JNJ         JNJ         JNJ       JNJ
# Date
# 2020-06-17  124.960625  126.175346  124.483408  125.724158   5100100
# 2020-06-18  124.431389  125.047421  123.095182  123.659170   4797400
# 2020-06-19  124.795799  126.574509  124.292554  126.496409  12206900
# 2020-06-22  124.414017  124.648289  123.233996  124.483431   5285600
# 2020-06-23  123.954155  125.012703  123.797969  124.717702   5921600
