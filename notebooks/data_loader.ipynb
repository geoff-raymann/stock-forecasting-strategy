# %%
import yfinance as yf

# Download 5 years of daily data
df = yf.download('AAPL', period='5y', interval='1d')

# Save to CSV for reusability
df.to_csv('../data/AAPL.csv')

# Preview
df.head()
# Out:
# /tmp/ipykernel_15936/3303736250.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', period='5y', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-07-16  93.826530  94.684381  93.226278  93.865414  110577600
# 2020-07-17  93.636971  94.434067  93.163084  94.278540   92186800
# 2020-07-20  95.610298  95.748820  93.379401  93.724489   90318000
# 2020-07-21  94.290718  96.477874  94.040411  96.402539  103433200
# 2020-07-22  94.555603  95.238481  93.904318  93.991801   89001600
