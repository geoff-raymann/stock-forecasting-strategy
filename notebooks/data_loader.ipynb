# %%
import yfinance as yf

# Download 5 years of daily data
df = yf.download('AAPL', period='5y', interval='1d')

# Save to CSV for reusability
df.to_csv('../data/AAPL.csv')

# Preview
df.head()
# Out:
# C:\Users\GODIWOUR\AppData\Local\Temp\ipykernel_22272\3303736250.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', period='5y', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-06-17  85.442444  86.368339  85.320935  86.307585  114406400
# 2020-06-18  85.476456  85.894446  84.866480  85.398688   96820400
# 2020-06-19  84.988014  86.650252  83.877423  86.183663  264476000
# 2020-06-22  87.211601  87.354981  85.335508  85.381682  135445200
# 2020-06-23  89.073120  90.494773  88.037864  88.458287  212155600
